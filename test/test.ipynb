# %%
import sys

sys.path.append('/workspaces/biotools')

import biotools

# %%
insulin_records = biotools.records_from('test/insulin_gene.fasta')

for record in insulin_records:
    biotools.find_orf(record.seq)
# Out:
# Reading Frame 0: (496, 903) (700, 903) (733, 903) (1012, 1143)
# Reading Frame 1: (239, 553) (251, 553)
# Reading Frame 2: None
# Reading Frame 0: (496, 903) (700, 903) (733, 903) (1012, 1143)
# Reading Frame 1: (239, 553) (251, 553)
# Reading Frame 2: None
